# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as stats
from state_space_setup import *
from policy_df_generator import *

# %%
Optim_policy = pd.read_csv('policy.csv')
Optim_policy['State'] = Optim_policy['State'].apply(lambda x: tuple(map(int, x.strip('()').split(','))))

maximum_parts = Optim_policy['State'].apply(lambda x: x[0]).max()
print("Maximum number of parts in the inventory:", maximum_parts)

state_space = get_state_space(maximum_parts)
# Out:
# Maximum number of parts in the inventory: 41

# %%
Luke_policy = generate_sS_policy_IL(s=7, S=8, max_parts=maximum_parts)
Luke_policy["IL"] = list(map(lambda x: x[0], state_space))
Luke_policy["IP"] = list(map(sum, state_space))
Luke_policy.loc[(Luke_policy["IL"] >= 8) & (Luke_policy["IL"] <= 10) & (Luke_policy["IP"] <= 39), "Order_size"] += 2
Luke_policy.loc[(Luke_policy["IL"] >= 8) & (Luke_policy["IL"] <= 10) & (Luke_policy["IP"] == 40), "Order_size"] += 1
Luke_policy.drop('IL', axis=1, inplace=True)
Luke_policy.drop('IP', axis=1, inplace=True)
Luke_policy.to_csv("intern_policies/Luke.csv", index=False)

# %%
Ben_policy = generate_sS_policy_IL(s=9, S=14, max_parts=maximum_parts)
Ben_policy.to_csv("intern_policies/Ben.csv", index=False)

# %%
Harriett_policy = generate_sS_policy_IL(s=29, S=41, max_parts=maximum_parts)
Harriett_policy.to_csv("intern_policies/Harriett.csv", index=False)

# %%
discount_factor = 0.995
cost_matrix = np.load("cost_matrix.npy")

def generate_demand(num_periods=1000, lambda_=2, p=0.9):
    demand = np.random.poisson(lam=lambda_, size=num_periods)
    arrivals = np.random.binomial(1, p, size=num_periods)

    return np.column_stack((demand, arrivals))


def apply_policy(initial_state, policy_df, demands):
    global maximum_parts, cost_matrix

    num_periods = len(demands)
    policy_dict = dict(zip(policy_df["State"], policy_df["Order_size"]))

    states = np.zeros((num_periods + 1, 2), dtype=int)
    actions = np.zeros(num_periods + 1, dtype=int)
    costs = np.zeros(num_periods + 1, dtype=float)

    states[0] = initial_state
    actions[0] = policy_dict[tuple(states[0])]
    costs[0] = 0

    for i in range(num_periods):
        current_state = states[i]
        current_idx = get_index(current_state[0], current_state[1], maximum_parts)
        action = actions[i]

        new_IL = max(0, current_state[0] - demands[i, 0]) + (current_state[1] + action) * demands[i, 1]
        new_OP = (current_state[1] + action) * (1 - demands[i, 1])
        
        new_idx = get_index(new_IL, new_OP, maximum_parts)
        cost = cost_matrix[current_idx, new_idx, action]
        costs[i+1] = cost

        states[i+1] = (new_IL, new_OP)
        actions[i+1] = policy_dict[(new_IL, new_OP)]

    SAC_df = pd.DataFrame({
        "States" : [tuple(s) for s in states],
        "Actions" : actions,
        "Costs" : costs
    })
    
    return SAC_df


def total_cost(simulated_data):
    global discount_factor
    
    factor_sequence = discount_factor ** np.arange(len(simulated_data["Costs"]))
    discounted_cost = np.sum(factor_sequence * np.array(simulated_data["Costs"]))
        
    return discounted_cost

# %%
state = (14, 0)
size = 1000
state_idx = get_index(state[0], state[1], maximum_parts)
sampled_costs_Luke = np.zeros(size)
sampled_costs_Ben = np.zeros(size)
sampled_costs_Optim = np.zeros(size)
sampled_costs_Harriett = np.zeros(size)

for i in range(size):
    demand = generate_demand(4000, 2, 0.9)
    sampled_costs_Luke[i] = total_cost(apply_policy(state, Luke_policy, demand))
    sampled_costs_Ben[i] = total_cost(apply_policy(state, Ben_policy, demand))
    sampled_costs_Optim[i] = total_cost(apply_policy(state, Optim_policy, demand))
    sampled_costs_Harriett[i] = total_cost(apply_policy(state, Harriett_policy, demand))
    if (i + 1) % 100 == 0:
        print(f"Sample {i + 1}/{size}:\n \
            Optimal policy cost = {sampled_costs_Optim[i]},\n \
            Luke's policy cost = {sampled_costs_Luke[i]},\n \
            Ben's policy cost = {sampled_costs_Ben[i]},\n \
            Harriett's policy cost = {sampled_costs_Harriett[i]}")
# Out:
# Sample 100/1000:
#              Optimal policy cost = 45929.80160514394,
#              Luke's policy cost = 112894.15967150842,
#              Ben's policy cost = 53442.96174958564,
#              Harriett's policy cost = 52223.66585671254
# Sample 200/1000:
#              Optimal policy cost = 44260.55132710069,
#              Luke's policy cost = 118585.65811509351,
#              Ben's policy cost = 58615.583512296354,
#              Harriett's policy cost = 50673.39302905391
# Sample 300/1000:
#              Optimal policy cost = 51787.65534703337,
#              Luke's policy cost = 147193.30640301516,
#              Ben's policy cost = 62064.816539367035,
#              Harriett's policy cost = 58241.50877995526
# Sample 400/1000:
#              Optimal policy cost = 46410.507055938324,
#              Luke's policy cost = 115107.25111729298,
#              Ben's policy cost = 55678.81141788674,
#              Harriett's policy cost = 52900.46760177432
# Sample 500/1000:
#              Optimal policy cost = 43056.163617285085,
#              Luke's policy cost = 95383.31045004106,
#              Ben's policy cost = 53936.92550145262,
#              Harriett's policy cost = 49259.41038877957
# Sample 600/1000:
#              Optimal policy cost = 46159.23806256902,
#              Luke's policy cost = 118606.38094741567,
#              Ben's policy cost = 55936.82657583309,
#              Harriett's policy cost = 52468.63035439587
# Sample 700/1000:
#              Optimal policy cost = 44002.963844725185,
#              Luke's policy cost = 87541.93870243496,
#              Ben's policy cost = 50305.13765315398,
#              Harriett's policy cost = 50138.76953454153
# Sample 800/1000:
#              Optimal policy cost = 50171.80694991016,
#              Luke's policy cost = 138404.45020060544,
#              Ben's policy cost = 62094.58594808148,
#              Harriett's policy cost = 56888.53660920881
# Sample 900/1000:
#              Optimal policy cost = 48322.96671243452,
#              Luke's policy cost = 113269.83207634544,
#              Ben's policy cost = 57723.679448574345,
#              Harriett's policy cost = 55012.81652510638
# Sample 1000/1000:
#              Optimal policy cost = 45186.68087854056,
#              Luke's policy cost = 120436.19786182189,
#              Ben's policy cost = 54456.42209079467,
#              Harriett's policy cost = 51816.66746711904

# %%
plt.figure(figsize=(8, 6))
plt.scatter(np.arange(len(sampled_costs_Optim)), sampled_costs_Optim, color='#A499F4', alpha=0.5)
plt.scatter(np.arange(len(sampled_costs_Luke)), sampled_costs_Luke, color='#F1977F', alpha=0.5)
plt.scatter(np.arange(len(sampled_costs_Ben)), sampled_costs_Ben, color='#51D7C1', alpha=0.5)
plt.scatter(np.arange(len(sampled_costs_Harriett)), sampled_costs_Harriett, color='#FEDE7B', alpha=0.5)
plt.axhline(np.mean(sampled_costs_Luke), color='#F1977F', linestyle='-', label='Mean Discounted Cost under Luke\'s Policy', alpha=0.7)
plt.axhline(np.mean(sampled_costs_Ben), color='#51D7C1', linestyle='-', label='Mean Discounted Cost under Ben\'s Policy', alpha=0.7)
plt.axhline(np.mean(sampled_costs_Harriett), color='#FEDE7B', linestyle='-', label='Mean Discounted Cost under Harriett\'s Policy', alpha=0.7)
plt.axhline(np.mean(sampled_costs_Optim), color='#A499F4', linestyle='-', label='Mean Discounted Cost under Optimal Policy', alpha=0.7)
plt.legend()
plt.title("Sampled Discounted Costs under Different Policies")
plt.xlabel("Sample Index")
plt.ylabel("Discounted Cost")
plt.savefig("plots/intern_policies.pdf", format="pdf", bbox_inches='tight')
plt.show()

print("The mean of the sampled costs under optimal policy:", np.mean(sampled_costs_Optim))
print("The mean of the sampled costs under Luke's policy:", np.mean(sampled_costs_Luke))
print("The mean of the sampled costs under Ben's policy", np.mean(sampled_costs_Ben))
print("The mean of the sampled costs under Harriett's policy", np.mean(sampled_costs_Harriett))
# Out:
# The mean of the sampled costs under optimal policy: 47505.177231944275
# The mean of the sampled costs under Luke's policy: 121989.95519762227
# The mean of the sampled costs under Ben's policy 60155.89354958087
# The mean of the sampled costs under Harriett's policy 53743.06086655381

# %%
state = (14, 0)
demand = generate_demand(103, 2, 0.9)

sample_Luke = apply_policy(state, Luke_policy, demand)
sample_Ben = apply_policy(state, Ben_policy, demand)
sample_Optim = apply_policy(state, Optim_policy, demand)
sample_Harriett = apply_policy(state, Harriett_policy, demand)

colours = {
    "Optim": "#A499F4",
    "Luke": "#F1977F",
    "Ben": "#51D7C1",
    "Harriett": "#FEDE7B"
}

IL_Luke = [state[0] for state in sample_Luke["States"]]
IL_Ben = [state[0] for state in sample_Ben["States"]]
IL_Optim = [state[0] for state in sample_Optim["States"]]
IL_Harriett = [state[0] for state in sample_Harriett["States"]]

plt.figure(figsize=(8, 6))
plt.plot(np.arange(len(sample_Luke)), IL_Luke, label="Luke's Policy", color=colours["Luke"], linewidth=1)
plt.plot(np.arange(len(sample_Ben)), IL_Ben, label="Ben's Policy", color=colours["Ben"], linewidth=1)
plt.plot(np.arange(len(sample_Harriett)), IL_Harriett, label="Harriett's Policy", color=colours["Harriett"], linewidth=1)
plt.plot(np.arange(len(sample_Optim)), IL_Optim, label="Optimal Policy", color=colours["Optim"], linewidth=2)
plt.ylabel("Inventory Level")
plt.xlabel("Week")
plt.title("Simulated Inventory Levels Over Time")
plt.grid(True, which="both", linestyle="-", linewidth=0.5, alpha=0.5)
plt.legend()
plt.tight_layout()
plt.savefig("plots/inventory_level_comparison.pdf", format="pdf", bbox_inches="tight")
plt.show()
